# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\Lenovo\Desktop\DS\chromedriver 100.exe")
driver.get('https://www.flipkart.com/')

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('routers')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')

# %%
df = pd.DataFrame({'Product':'Routers', 'Ratings':rati,'Reviews':revi})
df
# Out:
#      Product Ratings              Reviews
# 0    Routers       5            Just wow!
# 1    Routers       5       Classy product
# 2    Routers       5       Simply awesome
# 3    Routers       5   Highly recommended
# 4    Routers       5              Awesome
# ..       ...     ...                  ...
# 355  Routers       -                    -
# 356  Routers       5  Best in the market!
# 357  Routers       -                    -
# 358  Routers       -                    -
# 359  Routers       5        Great product
#
# [360 rows x 3 columns]

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('laptops')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')

# %%
df1 = pd.DataFrame({'Product':'Laptops', 'Ratings':rati,'Reviews':revi})
df1
# Out:
#      Product Ratings                                            Reviews
# 0    Laptops       -                                                  -
# 1    Laptops       5                                             Super!
# 2    Laptops       -                                                  -
# 3    Laptops       -                                                  -
# 4    Laptops       5                                   Perfect product!
# 5    Laptops       -                                                  -
# 6    Laptops       -                                                  -
# 7    Laptops       -                                                  -
# 8    Laptops       -                                                  -
# 9    Laptops       4                                        Good choice
# 10   Laptops       5                              Mind-blowing purchase
# 11   Laptops       4                                          Wonderful
# ...

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('Phones')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')

# %%
df2 = pd.DataFrame({'Product':'Phones', 'Ratings':rati,'Reviews':revi})
df2
# Out:
#     Product Ratings                                            Reviews
# 0    Phones       4                                        Really Nice
# 1    Phones       4                                        Really Nice
# 2    Phones       4                                        Good choice
# 3    Phones       5                                             Super!
# 4    Phones       5                                  Terrific purchase
# 5    Phones       4                                   day to day king.
# 6    Phones       4                                   day to day king.
# 7    Phones       5                                          Fabulous!
# 8    Phones       3                                          Just okay
# 9    Phones       3                                          Just okay
# 10   Phones       5                                          Fabulous!
# 11   Phones       5                                 Highly recommended
# ...

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('Headphones')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = 's1Q9rs']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')

# %%
df3 = pd.DataFrame({'Product':'Headphones', 'Ratings':rati,'Reviews':revi})
df3
# Out:
#         Product Ratings                       Reviews
# 0    Headphones       5             Terrific purchase
# 1    Headphones       5                Classy product
# 2    Headphones       5                 Great product
# 3    Headphones       4          Good quality product
# 4    Headphones       3                          Fair
# 5    Headphones       -                             -
# 6    Headphones       4                   Good choice
# 7    Headphones       4                   Really Nice
# 8    Headphones       -                             -
# 9    Headphones       4                   Pretty good
# 10   Headphones       3         Slightly disappointed
# 11   Headphones       3                  Does the job
# 12   Headphones       3                     Worthless
# 13   Headphones       5              Perfect product!
# 14   Headphones       5                        Super!
# 15   Headphones       5         Mind-blowing purchase
# ...

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('Smart Watches')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')

# %%
df4 = pd.DataFrame({'Product':'Smart Watches', 'Ratings':rati,'Reviews':revi})
df4
# Out:
#            Product Ratings                                            Reviews
# 0    Smart Watches       4                                        Pretty good
# 1    Smart Watches       4                                                  -
# 2    Smart Watches       -                                                  -
# 3    Smart Watches       5                                          Fabulous!
# 4    Smart Watches       5                              Mind-blowing purchase
# 5    Smart Watches       4                                         Delightful
# 6    Smart Watches       4                                         Delightful
# 7    Smart Watches       5  Super Smartwatch..Super Gbuddy...Super flipkar...
# 8    Smart Watches       5                                          Fabulous!
# 9    Smart Watches       5                                          Must buy!
# 10   Smart Watches       5                              Mind-blowing purchase
# ...

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('Professional Camera')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-124-d0e4f108d0d9> in <module>
#       1 rati = []
#       2 for i in urls:
# ----> 3     driver.get (i)
#       4     time.sleep(2)
#       5     try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
# ...

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')

# %%
len(rati)
# Out:
# 30

# %%
df5 = pd.DataFrame({'Product':'Professional Camera', 'Ratings':rati,'Reviews':revi})
df5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-1c211cf03efb> in <module>
# ----> 1 df5 = pd.DataFrame({'Product':'Professional Camera', 'Ratings':rati,'Reviews':revi})
#       2 df5
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('Printers')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')

# %%
df6 = pd.DataFrame({'Product':'Printers', 'Ratings':rati,'Reviews':revi})
df6
# Out:
#       Product Ratings                                            Reviews
# 0    Printers       5                                  Terrific purchase
# 1    Printers       5                                   Perfect product!
# 2    Printers       4                                         Delightful
# 3    Printers       5                                          Excellent
# 4    Printers       5                                            Awesome
# 5    Printers       5                                   Perfect product!
# 6    Printers       5                      pretty good first impressions
# 7    Printers       5                                     Classy product
# 8    Printers       5                                          Just wow!
# 9    Printers       5                                          Fabulous!
# 10   Printers       5                                          Excellent
# 11   Printers       5                                          Wonderful
# ...

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('Monitors')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_1fQZEK']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-155-0b79a459ed84> in <module>
#       1 revi = []
#       2 for i in urls:
# ----> 3     driver.get (i)
#       4     time.sleep(2)
#       5     try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
# ...

# %%
df7 = pd.DataFrame({'Product':'Monitors', 'Ratings':rati[:118],'Reviews':revi})
df7
# Out:
#       Product Ratings                            Reviews
# 0    Monitors       5                            Awesome
# 1    Monitors       5                  Worth every penny
# 2    Monitors       5                            Awesome
# 3    Monitors       4                        Good choice
# 4    Monitors       4                         Delightful
# 5    Monitors       5                          Just wow!
# 6    Monitors       5                             Super!
# 7    Monitors       5                            Awesome
# 8    Monitors       4                         Delightful
# 9    Monitors       5                          Wonderful
# 10   Monitors       5                          Excellent
# 11   Monitors       5                            Awesome
# 12   Monitors       5                      Great product
# 13   Monitors       5  Great product at this price range
# 14   Monitors       5                            Awesome
# ...

# %%
driver = webdriver.Chrome(r"D:\DS\chromedriver.exe")
driver.get('https://www.flipkart.com/')

# %%
searc_prod = driver.find_element_by_xpath ("//div[@class = '_3OO5Xc']/input")
searc_prod.send_keys ('Home Theatre')
butt = driver.find_element_by_xpath ("//button[@class = 'L0Z3Pu']")
butt.click()

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M']")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][2]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][3]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][4]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][5]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][6]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][7]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][8]")
nextp.click()

# %%
for i in driver.find_elements_by_xpath("//a[@class = '_2rpwqI']"):
    urls.append(i.get_attribute('href'))
nextp = driver.find_element_by_xpath ("//a[@class ='ge-49M'][9]")
nextp.click()

# %%
rati = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rat = driver.find_element_by_xpath ("//div[@class = '_3LWZlK _1BLPMq']")
        rati.append(rat.text)
    except:
        rati.append('-')

# %%
revi = []
for i in urls:
    driver.get (i)
    time.sleep(2)
    try:
        rev = driver.find_element_by_xpath ("//p[@class = '_2-N8zT']")
        revi.append(rev.text)
    except:
        revi.append('-')

# %%
df8 = pd.DataFrame({'Product':'Home theater', 'Ratings':rati,'Reviews':revi})
df8
# Out:
#           Product Ratings              Reviews
# 0    Home theater       5            Just wow!
# 1    Home theater       5       Classy product
# 2    Home theater       5       Simply awesome
# 3    Home theater       5   Highly recommended
# 4    Home theater       5              Awesome
# ..            ...     ...                  ...
# 355  Home theater       -                    -
# 356  Home theater       5  Best in the market!
# 357  Home theater       -                    -
# 358  Home theater       -                    -
# 359  Home theater       5        Great product
#
# [360 rows x 3 columns]

# %%
dataframe = pd.concat([df,df1,df2,df3,df4,df6,df7,df8])
dataframe

# %%
dataframe.to_excel(reviews_ratings)
