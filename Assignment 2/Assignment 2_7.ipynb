# %%
# Write a python program to scrape house details from mentioned URL. It should include house title, location, area, EMI and price from nobroker.in.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
#Chennai
page = requests.get ('https://www.nobroker.in/property/sale/chennai/Chennai/?searchParam=W3sibGF0IjoxMy4wNDM3NjEyODI5MTkyLCJsb24iOjgwLjIwMDA2ODUxNjk2OTMsInBsYWNlSWQiOiJDaElKWVROOVQtcGxVam9STTlSamFBdW5ZVzQiLCJwbGFjZU5hbWUiOiJDaGVubmFpIiwic2hvd01hcCI6ZmFsc2V9XQ==')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
title = []
for i in soup.find_all ('h2', class_ = 'heading-6 font-semi-bold nb__25Cl7'):
    title.append(i.text)
title
# Out:
# ['2 BHK Flat  For Sale  In Vijay Rajas Century Court, Poonamallee In Mevalurkuppam Village, Madras Bombay Trunk Road ',
#  '3 BHK Flat  For Sale  In Ceedeeyes Regal Palm Gardens, Velachery In Velachery ',
#  '2 BHK Flat  For Sale  In Sai Palace In Sholinganallur ',
#  '2 BHK Apartment  For Sale  In Jains Abhineet In Villivakkam ',
#  '4 BHK In Independent House  For Sale  In Iyyappanthangal ',
#  '2 BHK Apartment  For Sale  In Jains Nakshatra In Chinna Nolambur ',
#  '2 BHK Flat  For Sale  In Sandhiya Paradise In Madambakkam ',
#  '2 BHK Flat  For Sale  In Surya Apartment In Choolaimedu ',
#  '3 BHK Flat  For Sale  In Xs Real Vibe In Pallikaranai ',
#  '4+ BHK In Independent House  For Sale  In Ernavur, Ennore ',
#  '2 BHK Apartment  For Sale  In Eta Jasmine Court In Iyyappanthangal ',
#  '3 BHK Flat  For Sale  In Keerthis Jayam In Thoraipakkam ',
#  '2 BHK Flat  For Sale  In Apartment  In George Town ',
#  '3 BHK Apartment  For Sale  In Fantastic By Urban Tree In Vanagaram ',
# ...

# %%
location = []
for i in soup.find_all ('div', class_ = 'nb__1EwQz'):
    location.append(i.text)
location
# Out:
# ['Melurkuppam Main Road,, Padur Village, Poonammallee, Chennai, Tamil Nadu, INDIA.',
#  'Next to Adyar Ananda Bhawan Hotel',
#  'near Sri Prathyangira Devi Temple',
#  'Jains Abhineet\xa0 No.29, 1st Street, Rajamangalam, Villivakkam,asjacent to villivakkam railway station, Chennai, Tamil Nadu, INDIA.',
#  'Independent House, Ashok Brindavan, Iyyappanthangal, Chennai, Tamil Nadu, India',
#  'Jains Nakshatra\xa0 Union Rd, Chinna Nolambur, Chennai, Tamil Nadu 600095, India',
#  ' ganapathy nagar, near EB office madambakkam ',
#  '4th Street Near Seventh-day Adventist Schoo;',
#  '3rd Cross Street',
#  'Independent House, ITC ,RAMAKRISHNA NAGAR 1ST STREET Ernavoor',
#  'Eta Jasmine Court\xa0  Mount Poonamallee Rd, Jayalakshmi Nagar, Goparasanallur',
#  'sai nagar , near tollgate and chennai one building  , thoraipakkam ',
#  'Prakasam Road near Broadway Theatre',
#  'Fantastic By Urban Tree\xa0 Adjacent to, Noombal Icon, Vanagaram, Chennai, Tamil Nadu, India',
# ...

# %%
header = []
for i in soup.find_all ('div', class_ = 'font-semi-bold heading-6'):
    header.append(i.text)
header
# Out:
# ['873 sqft',
#  '₹16,048/Month',
#  '₹28 Lacs',
#  '1,950 sqft',
#  '₹77,374/Month',
#  '₹1.35 Crores',
#  '958 sqft',
#  '₹22,925/Month',
#  '₹40 Lacs',
#  '871 sqft',
#  '₹35,534/Month',
#  '₹62 Lacs',
#  '2,500 sqft',
#  '₹1.2 Lacs/Month',
#  '₹2.1 Crores',
#  '1,113 sqft',
#  '₹33,242/Month',
#  '₹58 Lacs',
#  '1,004 sqft',
#  '₹27,510/Month',
#  '₹48 Lacs',
#  '570 sqft',
#  '₹22,868/Month',
#  '₹39.9 Lacs',
#  '1,136 sqft',
#  '₹37,254/Month',
#  '₹65 Lacs',
#  '2,400 sqft',
#  '₹91,703/Month',
#  '₹1.6 Crores',
#  '1,154 sqft',
#  '₹31,522/Month',
#  '₹55 Lacs',
#  '1,173 sqft',
#  '₹40,693/Month',
#  '₹71 Lacs',
#  '765 sqft',
#  '₹29,803/Month',
#  '₹52 Lacs',
#  '1,358 sqft',
#  '₹51,583/Month',
#  '₹90 Lacs',
#  '670 sqft',
#  '₹1.15 Lacs/Month',
#  '₹2 Crores',
#  '1,850 sqft',
#  '₹77,374/Month',
#  '₹1.35 Crores',
#  '1,250 sqft',
#  '₹71,643/Month',
#  '₹1.25 Crores',
#  '1,550 sqft',
#  '₹60,180/Month',
#  '₹1.05 Crores',
#  '1,100 sqft',
#  '₹68,777/Month',
# ...

# %%
del header[0:76:3]
header
# Out:
# ['₹16,048/Month',
#  '₹28 Lacs',
#  '₹77,374/Month',
#  '₹1.35 Crores',
#  '₹22,925/Month',
#  '₹40 Lacs',
#  '₹35,534/Month',
#  '₹62 Lacs',
#  '₹1.2 Lacs/Month',
#  '₹2.1 Crores',
#  '₹33,242/Month',
#  '₹58 Lacs',
#  '₹27,510/Month',
#  '₹48 Lacs',
#  '₹22,868/Month',
#  '₹39.9 Lacs',
#  '₹37,254/Month',
#  '₹65 Lacs',
#  '₹91,703/Month',
#  '₹1.6 Crores',
#  '₹31,522/Month',
#  '₹55 Lacs',
#  '₹40,693/Month',
#  '₹71 Lacs',
#  '₹29,803/Month',
#  '₹52 Lacs',
#  '₹51,583/Month',
#  '₹90 Lacs',
#  '₹1.15 Lacs/Month',
#  '₹2 Crores',
#  '₹77,374/Month',
#  '₹1.35 Crores',
#  '₹71,643/Month',
#  '₹1.25 Crores',
#  '₹60,180/Month',
#  '₹1.05 Crores',
#  '₹68,777/Month',
#  '₹1.2 Crores',
#  '₹38,400/Month',
#  '₹67 Lacs',
#  '₹34,388/Month',
#  '₹60 Lacs',
#  '₹24,072/Month',
#  '₹42 Lacs',
#  '₹75,655/Month',
#  '₹1.32 Crores',
#  '₹42,985/Month',
#  '₹75 Lacs',
#  '₹63,045/Month',
#  '₹1.1 Crores']

# %%
emi = header[0:51:2]
emi
# Out:
# ['₹16,048/Month',
#  '₹77,374/Month',
#  '₹22,925/Month',
#  '₹35,534/Month',
#  '₹1.2 Lacs/Month',
#  '₹33,242/Month',
#  '₹27,510/Month',
#  '₹22,868/Month',
#  '₹37,254/Month',
#  '₹91,703/Month',
#  '₹31,522/Month',
#  '₹40,693/Month',
#  '₹29,803/Month',
#  '₹51,583/Month',
#  '₹1.15 Lacs/Month',
#  '₹77,374/Month',
#  '₹71,643/Month',
#  '₹60,180/Month',
#  '₹68,777/Month',
#  '₹38,400/Month',
#  '₹34,388/Month',
#  '₹24,072/Month',
#  '₹75,655/Month',
#  '₹42,985/Month',
#  '₹63,045/Month']

# %%
price = header[1:51:2]
price
# Out:
# ['₹28 Lacs',
#  '₹1.35 Crores',
#  '₹40 Lacs',
#  '₹62 Lacs',
#  '₹2.1 Crores',
#  '₹58 Lacs',
#  '₹48 Lacs',
#  '₹39.9 Lacs',
#  '₹65 Lacs',
#  '₹1.6 Crores',
#  '₹55 Lacs',
#  '₹71 Lacs',
#  '₹52 Lacs',
#  '₹90 Lacs',
#  '₹2 Crores',
#  '₹1.35 Crores',
#  '₹1.25 Crores',
#  '₹1.05 Crores',
#  '₹1.2 Crores',
#  '₹67 Lacs',
#  '₹60 Lacs',
#  '₹42 Lacs',
#  '₹1.32 Crores',
#  '₹75 Lacs',
#  '₹1.1 Crores']

# %%
print (len (location), len(title), len(emi), len (price))
# Out:
# 25 25 25 25

# %%
df1 = pd.DataFrame({'House title': title,'Location':location,'Area':'Chennai','EMI':emi,'Price':price})
df1
# Out:
#                                           House title  \
# 0   2 BHK Flat  For Sale  In Vijay Rajas Century C...
# 1   3 BHK Flat  For Sale  In Ceedeeyes Regal Palm ...
# 2   2 BHK Flat  For Sale  In Sai Palace In Sholing...
# 3   2 BHK Apartment  For Sale  In Jains Abhineet I...
# 4   4 BHK In Independent House  For Sale  In Iyyap...
# 5   2 BHK Apartment  For Sale  In Jains Nakshatra ...
# 6   2 BHK Flat  For Sale  In Sandhiya Paradise In ...
# 7   2 BHK Flat  For Sale  In Surya Apartment In Ch...
# 8   3 BHK Flat  For Sale  In Xs Real Vibe In Palli...
# 9   4+ BHK In Independent House  For Sale  In Erna...
# 10  2 BHK Apartment  For Sale  In Eta Jasmine Cour...
# 11  3 BHK Flat  For Sale  In Keerthis Jayam In Tho...
# 12  2 BHK Flat  For Sale  In Apartment  In George ...
# 13  3 BHK Apartment  For Sale  In Fantastic By Urb...
# 14  1 BHK In Independent House  For Sale  In Ambat...
# 15  4 BHK In Independent House  For Sale  In Ambat...
# ...

# %%
#Bangalore

# %%
page = requests.get ('https://www.nobroker.in/property/sale/bangalore/Bangalore/?searchParam=W3sibGF0IjoxMi45Njk5MzM0NDAzNjgxLCJsb24iOjc3LjU5ODE3NzAzMjg1MjIsInBsYWNlSWQiOiJDaElKYlU2MHlYQVdyanNSNEU5LVVlakQzX2ciLCJwbGFjZU5hbWUiOiJCYW5nYWxvcmUiLCJzaG93TWFwIjpmYWxzZX1d')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
title = []
for i in soup.find_all ('h2', class_ = 'heading-6 font-semi-bold nb__25Cl7'):
    title.append(i.text)
title
# Out:
# ['2 BHK Apartment  For Sale  In Shriram Sahaana In Yelahanka ',
#  '3 BHK Flat  For Sale  In Saveria Winston Apartment In Kadubeesanahalli ',
#  '2 BHK Flat  For Sale  In Btm Residency In Jp Nagar 5th Phase ',
#  '2 BHK Apartment  For Sale  In Vijayasri Elixir In Whitefield ',
#  '3 BHK Flat  For Sale  In Sjr Spencer In Marathahalli ',
#  '2 BHK Apartment  For Sale  In Mahaveer Coral In Jp Nagar 5th Phase ',
#  '3 BHK Apartment  For Sale  In Shravanthi Woods Apartments In Kalena Agrahara ',
#  '2 BHK Apartment  For Sale  In Costa Coral Reef In Beratena Agrahara ',
#  '3 BHK Flat  For Sale  In Brigade Panorama In Anchepalya ',
#  '2 BHK Apartment  For Sale  In Metro Marvel In Kaval Bairasandra ',
#  '2 BHK Apartment  For Sale  In Gr Queens Pride In Begur ',
#  '3 BHK Apartment  For Sale  In Prestige Fontaine Bleau In Whitefield ',
#  '2 BHK In Independent House  For Sale  In Andrahalli ',
#  '3 BHK Flat  For Sale  In Sanjana Sri Hari Palace In Banashankari 3rd Stage ',
# ...

# %%
location = []
for i in soup.find_all ('div', class_ = 'nb__1EwQz'):
    location.append(i.text)
location
# Out:
# ['Shriram Sahaana\xa0 Opp BMSIT, Doddaballapur Rd, Yelahanka, Karnataka, India',
#  'Doddakannelli - Kaadubeesanahalli Rd, Kaverappa Layout, Kadubeesanahalli, Bengaluru, Karnataka 560103, India',
#  '15th Main Rd, 5th Phase, Nanjundeswara Layout near Esteem Park Apartment',
#  'Vijayasri Elixir\xa0 3 & 4, Borewell Rd, Palm Meadows, Nallurhalli, Whitefield, Bengaluru, Karnataka 560066, India',
#  'SJR Spencer, Aswath Nagar, Marathahalli, Bengaluru, Karnataka 560037, India',
#  'Mahaveer Coral\xa0 Sai Ganesh Residency 17th Cross, 15th Main Rd, 5th Phase, Nanjundeswara Layout, J P Nagar Phase 5, J. P. Nagar, Bengaluru, Karnataka 560078, India',
#  'Shravanthi Woods Apartments\xa0 Nobo Nagar, Kalena Agrahara, Bengaluru, Karnataka 560076, India',
#  'Costa Coral Reef\xa0  Costa Infra Pvt Ltd, Opp. Bosch Beretena Agrahara, New Mico Rd, Bengaluru, Karnataka 560100',
#  'Survey No. 43/5, 43/30 & 238, Mysuru main road, Kambipura, Anchepalya, Bengaluru, Karnataka 560060, India',
# ...

# %%
header = []
for i in soup.find_all ('div', class_ = 'font-semi-bold heading-6'):
    header.append(i.text)
header
# Out:
# ['1,207 sqft',
#  '₹40,120/Month',
#  '₹70 Lacs',
#  '1,475 sqft',
#  '₹51,583/Month',
#  '₹90 Lacs',
#  '1,112 sqft',
#  '₹20,060/Month',
#  '₹35 Lacs',
#  '1,255 sqft',
#  '₹38,973/Month',
#  '₹68 Lacs',
#  '1,610 sqft',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '1,140 sqft',
#  '₹34,388/Month',
#  '₹60 Lacs',
#  '1,515 sqft',
#  '₹38,973/Month',
#  '₹68 Lacs',
#  '1,200 sqft',
#  '₹32,096/Month',
#  '₹56 Lacs',
#  '1,584 sqft',
#  '₹57,887/Month',
#  '₹1.01 Crores',
#  '1,050 sqft',
#  '₹28,657/Month',
#  '₹50 Lacs',
#  '920 sqft',
#  '₹25,791/Month',
#  '₹45 Lacs',
#  '1,356 sqft',
#  '₹64,765/Month',
#  '₹1.13 Crores',
#  '2,600 sqft',
#  '₹54,448/Month',
#  '₹95 Lacs',
#  '1,560 sqft',
#  '₹83,106/Month',
#  '₹1.45 Crores',
#  '712 sqft',
#  '₹21,779/Month',
#  '₹38 Lacs',
#  '1,752 sqft',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '1,933 sqft',
#  '₹97,434/Month',
#  '₹1.7 Crores',
#  '2,010 sqft',
#  '₹1.35 Lacs/Month',
#  '₹2.35 Crores',
#  '2,500 sqft',
#  '₹1.38 Lacs/Month',
# ...

# %%
del header[0:76:3]
header
# Out:
# ['₹40,120/Month',
#  '₹70 Lacs',
#  '₹51,583/Month',
#  '₹90 Lacs',
#  '₹20,060/Month',
#  '₹35 Lacs',
#  '₹38,973/Month',
#  '₹68 Lacs',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '₹34,388/Month',
#  '₹60 Lacs',
#  '₹38,973/Month',
#  '₹68 Lacs',
#  '₹32,096/Month',
#  '₹56 Lacs',
#  '₹57,887/Month',
#  '₹1.01 Crores',
#  '₹28,657/Month',
#  '₹50 Lacs',
#  '₹25,791/Month',
#  '₹45 Lacs',
#  '₹64,765/Month',
#  '₹1.13 Crores',
#  '₹54,448/Month',
#  '₹95 Lacs',
#  '₹83,106/Month',
#  '₹1.45 Crores',
#  '₹21,779/Month',
#  '₹38 Lacs',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '₹97,434/Month',
#  '₹1.7 Crores',
#  '₹1.35 Lacs/Month',
#  '₹2.35 Crores',
#  '₹1.38 Lacs/Month',
#  '₹2.41 Crores',
#  '₹73,935/Month',
#  '₹1.29 Crores',
#  '₹31,522/Month',
#  '₹55 Lacs',
#  '₹2.01 Lacs/Month',
#  '₹3.5 Crores',
#  '₹42,985/Month',
#  '₹75 Lacs',
#  '₹35,534/Month',
#  '₹62 Lacs',
#  '₹42,985/Month',
#  '₹75 Lacs']

# %%
emi = header[0:51:2]
emi
# Out:
# ['₹40,120/Month',
#  '₹51,583/Month',
#  '₹20,060/Month',
#  '₹38,973/Month',
#  '₹48,717/Month',
#  '₹34,388/Month',
#  '₹38,973/Month',
#  '₹32,096/Month',
#  '₹57,887/Month',
#  '₹28,657/Month',
#  '₹25,791/Month',
#  '₹64,765/Month',
#  '₹54,448/Month',
#  '₹83,106/Month',
#  '₹21,779/Month',
#  '₹74,508/Month',
#  '₹97,434/Month',
#  '₹1.35 Lacs/Month',
#  '₹1.38 Lacs/Month',
#  '₹73,935/Month',
#  '₹31,522/Month',
#  '₹2.01 Lacs/Month',
#  '₹42,985/Month',
#  '₹35,534/Month',
#  '₹42,985/Month']

# %%
price = header[1:51:2]
price
# Out:
# ['₹70 Lacs',
#  '₹90 Lacs',
#  '₹35 Lacs',
#  '₹68 Lacs',
#  '₹85 Lacs',
#  '₹60 Lacs',
#  '₹68 Lacs',
#  '₹56 Lacs',
#  '₹1.01 Crores',
#  '₹50 Lacs',
#  '₹45 Lacs',
#  '₹1.13 Crores',
#  '₹95 Lacs',
#  '₹1.45 Crores',
#  '₹38 Lacs',
#  '₹1.3 Crores',
#  '₹1.7 Crores',
#  '₹2.35 Crores',
#  '₹2.41 Crores',
#  '₹1.29 Crores',
#  '₹55 Lacs',
#  '₹3.5 Crores',
#  '₹75 Lacs',
#  '₹62 Lacs',
#  '₹75 Lacs']

# %%
print (len (location), len(title), len(emi), len (price))
# Out:
# 25 25 25 25

# %%
df2 = pd.DataFrame({'House title': title,'Location':location,'Area':'Bangalore','EMI':emi,'Price':price})
df2
# Out:
#                                           House title  \
# 0   2 BHK Apartment  For Sale  In Shriram Sahaana ...
# 1   3 BHK Flat  For Sale  In Saveria Winston Apart...
# 2   2 BHK Flat  For Sale  In Btm Residency In Jp N...
# 3   2 BHK Apartment  For Sale  In Vijayasri Elixir...
# 4   3 BHK Flat  For Sale  In Sjr Spencer In Marath...
# 5   2 BHK Apartment  For Sale  In Mahaveer Coral I...
# 6   3 BHK Apartment  For Sale  In Shravanthi Woods...
# 7   2 BHK Apartment  For Sale  In Costa Coral Reef...
# 8   3 BHK Flat  For Sale  In Brigade Panorama In A...
# 9   2 BHK Apartment  For Sale  In Metro Marvel In ...
# 10  2 BHK Apartment  For Sale  In Gr Queens Pride ...
# 11  3 BHK Apartment  For Sale  In Prestige Fontain...
# 12  2 BHK In Independent House  For Sale  In Andra...
# 13  3 BHK Flat  For Sale  In Sanjana Sri Hari Pala...
# 14  2 BHK Flat  For Sale  In Sai Amrut Nivas In Ar...
# 15  3 BHK Apartment  For Sale  In Bren Celestia In...
# ...

# %%
#Mumbai

# %%
page = requests.get ('https://www.nobroker.in/property/sale/mumbai/Mumbai/?searchParam=W3sibGF0IjoxOS4xMjMyNjI2MTEzMzc1LCJsb24iOjcyLjg3NzE3MDcyNjA1MzgsInBsYWNlSWQiOiJDaElKd2UxRVpqREc1enNSYVl4a2pZX3RwRjAiLCJwbGFjZU5hbWUiOiJNdW1iYWkiLCJzaG93TWFwIjpmYWxzZX1d')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
title = []
for i in soup.find_all ('h2', class_ = 'heading-6 font-semi-bold nb__25Cl7'):
    title.append(i.text)
title
# Out:
# ['1 BHK Flat  For Sale  In Saurabh Chs In Gavanpada Road, Mulund East ',
#  '3 BHK Flat  For Sale  In Chaitanya Building In Dadar East ',
#  '4 BHK Flat  For Sale  In Rustomjee Crown Phase I In Prabhadevi ',
#  '3 BHK Flat  For Sale  In Rustomjee Crown Phase I In Prabhadevi ',
#  '2 BHK Flat  For Sale  In Konark Chandralok In Ghatkopar East ',
#  '1 BHK Flat  For Sale  In Ire Chs In Charat Singh Colony ',
#  '2 BHK Flat  For Sale  In Mangalam Apartment In Vile Parle  ',
#  '3 BHK Flat  For Sale  In Sayaji Crest In Vile Parle (east) ',
#  '2 BHK Flat  For Sale  In Joy Homes In Bhandup West ',
#  '1 RK Flat  For Sale  In Sadarnagar Panchsheel Chs No 1 In Sardar Nagar Number 1 ',
#  '1 BHK Flat  For Sale  In Sri Narayan Chs In Ghatkopar West ',
#  '1 BHK Apartment  For Sale  In Blue Heaven In Kandivali East ',
#  '1 BHK Flat  For Sale  In Ekta Society Tilak Nagar   In Chembur East ',
#  '1 BHK Flat  For Sale  In Hill View Garden In Dahisar East ',
# ...

# %%
location = []
for i in soup.find_all ('div', class_ = 'nb__1EwQz'):
    location.append(i.text)
location
# Out:
# ['Vasudeo Balwant Phadke Road, Gavanpads, Mulund East',
#  'road no 4 near dadar railway station  and Kotak Mahindra Bank Ltd',
#  'Gokale Road, Prabhadevi, Mumbai, Maharashtra, INDIA.',
#  'Gokale Road, Prabhadevi, Mumbai, Maharashtra, INDIA.',
#  'Jethabhai Lane,near parakh hospital ',
#  'Dragonfly Hotel, Solitairer Corporate park',
#  'Irla Lane Navpad near KLS memorial hospital,',
#  'Sector 23',
#  'near bhandup station,   beside neptune magnet mall',
#  'Samaj Mandir Hall / Sardar Nagar, Sardar Nagar MHADA Colony',
#  'Jagdusha Nagar, Ghatkopar West, Mumbai, Maharashtra, INDIA',
#  'Blue Heaven\xa0 THAKUR COMPLEX  Kandivali East, Mumbai, Maharashtra, INDIA',
#  'Tilak Nagar  , NEAR NOBLE CHEMIST',
#  'vaishali nagar oppo bhairav nath mandir',
#  'Jaydeep Nagar, Near Nahur Railway station',
#  'Vithaldas Nagar near Guru Harkishan High School',
#  'OPPO ABHYUDAYA CO-OPERATIVE BANK',
#  'NEAR SHEETAL TALAO BEHIND SHEETAL TALKIES ',
#  'opp shiv leela restaurant ',
# ...

# %%
header = []
for i in soup.find_all ('div', class_ = 'font-semi-bold heading-6'):
    header.append(i.text)
header
# Out:
# ['525 sqft',
#  '₹94,568/Month',
#  '₹1.65 Crores',
#  '2,100 sqft',
#  '₹4.59 Lacs/Month',
#  '₹8 Crores',
#  '2,860 sqft',
#  '₹8.76 Lacs/Month',
#  '₹15.28 Crores',
#  '2,132 sqft',
#  '₹5 Lacs/Month',
#  '₹8.72 Crores',
#  '1,540 sqft',
#  '₹1.6 Lacs/Month',
#  '₹2.8 Crores',
#  '590 sqft',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '900 sqft',
#  '₹1.29 Lacs/Month',
#  '₹2.25 Crores',
#  '1,064 sqft',
#  '₹2.42 Lacs/Month',
#  '₹4.23 Crores',
#  '629 sqft',
#  '₹83,106/Month',
#  '₹1.45 Crores',
#  '325 sqft',
#  '₹33,242/Month',
#  '₹58 Lacs',
#  '580 sqft',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '575 sqft',
#  '₹57,314/Month',
#  '₹1 Crore',
#  '600 sqft',
#  '₹65,911/Month',
#  '₹1.15 Crores',
#  '565 sqft',
#  '₹37,254/Month',
#  '₹65 Lacs',
#  '656 sqft',
#  '₹63,045/Month',
#  '₹1.1 Crores',
#  '1,200 sqft',
#  '₹2.41 Lacs/Month',
#  '₹4.2 Crores',
#  '650 sqft',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '620 sqft',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '520 sqft',
# ...

# %%
del header[0:76:3]
header
# Out:
# ['₹94,568/Month',
#  '₹1.65 Crores',
#  '₹4.59 Lacs/Month',
#  '₹8 Crores',
#  '₹8.76 Lacs/Month',
#  '₹15.28 Crores',
#  '₹5 Lacs/Month',
#  '₹8.72 Crores',
#  '₹1.6 Lacs/Month',
#  '₹2.8 Crores',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '₹1.29 Lacs/Month',
#  '₹2.25 Crores',
#  '₹2.42 Lacs/Month',
#  '₹4.23 Crores',
#  '₹83,106/Month',
#  '₹1.45 Crores',
#  '₹33,242/Month',
#  '₹58 Lacs',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '₹57,314/Month',
#  '₹1 Crore',
#  '₹65,911/Month',
#  '₹1.15 Crores',
#  '₹37,254/Month',
#  '₹65 Lacs',
#  '₹63,045/Month',
#  '₹1.1 Crores',
#  '₹2.41 Lacs/Month',
#  '₹4.2 Crores',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '₹92,849/Month',
#  '₹1.62 Crores',
#  '₹12,609/Month',
#  '₹22 Lacs',
#  '₹83,106/Month',
#  '₹1.45 Crores',
#  '₹65,911/Month',
#  '₹1.15 Crores',
#  '₹2.9 Lacs/Month',
#  '₹5.06 Crores',
#  '₹2.27 Lacs/Month',
#  '₹3.96 Crores',
#  '₹1.23 Lacs/Month',
#  '₹2.15 Crores']

# %%
emi = header[0:51:2]
emi
# Out:
# ['₹94,568/Month',
#  '₹4.59 Lacs/Month',
#  '₹8.76 Lacs/Month',
#  '₹5 Lacs/Month',
#  '₹1.6 Lacs/Month',
#  '₹74,508/Month',
#  '₹1.29 Lacs/Month',
#  '₹2.42 Lacs/Month',
#  '₹83,106/Month',
#  '₹33,242/Month',
#  '₹48,717/Month',
#  '₹57,314/Month',
#  '₹65,911/Month',
#  '₹37,254/Month',
#  '₹63,045/Month',
#  '₹2.41 Lacs/Month',
#  '₹74,508/Month',
#  '₹74,508/Month',
#  '₹92,849/Month',
#  '₹12,609/Month',
#  '₹83,106/Month',
#  '₹65,911/Month',
#  '₹2.9 Lacs/Month',
#  '₹2.27 Lacs/Month',
#  '₹1.23 Lacs/Month']

# %%
price = header[1:51:2]
price
# Out:
# ['₹1.65 Crores',
#  '₹8 Crores',
#  '₹15.28 Crores',
#  '₹8.72 Crores',
#  '₹2.8 Crores',
#  '₹1.3 Crores',
#  '₹2.25 Crores',
#  '₹4.23 Crores',
#  '₹1.45 Crores',
#  '₹58 Lacs',
#  '₹85 Lacs',
#  '₹1 Crore',
#  '₹1.15 Crores',
#  '₹65 Lacs',
#  '₹1.1 Crores',
#  '₹4.2 Crores',
#  '₹1.3 Crores',
#  '₹1.3 Crores',
#  '₹1.62 Crores',
#  '₹22 Lacs',
#  '₹1.45 Crores',
#  '₹1.15 Crores',
#  '₹5.06 Crores',
#  '₹3.96 Crores',
#  '₹2.15 Crores']

# %%
print (len (location), len(title), len(emi), len (price))
# Out:
# 25 25 25 25

# %%
df3= pd.DataFrame({'House title': title,'Location':location,'Area':'Mumbai','EMI':emi,'Price':price})
df3
# Out:
#                                           House title  \
# 0   1 BHK Flat  For Sale  In Saurabh Chs In Gavanp...
# 1   3 BHK Flat  For Sale  In Chaitanya Building In...
# 2   4 BHK Flat  For Sale  In Rustomjee Crown Phase...
# 3   3 BHK Flat  For Sale  In Rustomjee Crown Phase...
# 4   2 BHK Flat  For Sale  In Konark Chandralok In ...
# 5   1 BHK Flat  For Sale  In Ire Chs In Charat Sin...
# 6   2 BHK Flat  For Sale  In Mangalam Apartment In...
# 7   3 BHK Flat  For Sale  In Sayaji Crest In Vile ...
# 8   2 BHK Flat  For Sale  In Joy Homes In Bhandup ...
# 9   1 RK Flat  For Sale  In Sadarnagar Panchsheel ...
# 10  1 BHK Flat  For Sale  In Sri Narayan Chs In Gh...
# 11  1 BHK Apartment  For Sale  In Blue Heaven In K...
# 12  1 BHK Flat  For Sale  In Ekta Society Tilak Na...
# 13  1 BHK Flat  For Sale  In Hill View Garden In D...
# 14  1 BHK Flat  For Sale  In Prashant Sagar Chs In...
# 15  3 BHK Flat  For Sale  In Omkar  In Santacruz W...
# ...

# %%
#Pune

# %%
page = requests.get ('https://www.nobroker.in/property/sale/pune/Pune/?searchParam=W3sibGF0IjoxOC41ODczNjU5NTA4ODc4LCJsb24iOjczLjg3Njc5MTY2MTYxMDEsInBsYWNlSWQiOiJDaElKQVJGR1p5Nl93anNSUS1PZW5iOURqWUkiLCJwbGFjZU5hbWUiOiJQdW5lIiwic2hvd01hcCI6ZmFsc2V9XQ==')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
title = []
for i in soup.find_all ('h2', class_ = 'heading-6 font-semi-bold nb__25Cl7'):
    title.append(i.text)
title
# Out:
# ['3 BHK Apartment  For Sale  In Anshul Eva Housing Society In Bavdhan ',
#  '2 BHK Apartment  For Sale  In Amit Colori In Undri ',
#  '2 BHK Flat  For Sale  In Ashirwad Sonai In Pimpri-chinchwad ',
#  '2 BHK Flat  For Sale  In Nalanda In Aundh ',
#  '2 BHK Apartment  For Sale  In Vaidehi Riviera In Bavdhan ',
#  '2 BHK Flat  For Sale  In Adityas A Garden City In Warje ',
#  '1 BHK Apartment  For Sale  In River Residency In Chikhali ',
#  '2 BHK Apartment  For Sale  In Rps Tower In Lohegaon ',
#  '2 BHK Flat  For Sale  In Ivana Society In Wakad Pune ',
#  '2 BHK Flat  For Sale  In Sai Subhash Srushti In Vadgaon Sheri ',
#  '1 BHK Apartment  For Sale  In Nilay Paradise In Ravet ',
#  '2 BHK Flat  For Sale  In Crystal Heights In Wakad ',
#  '3 BHK Apartment  For Sale  In Ranjeet Ss Tanishque Garden In Undri ',
#  '1 BHK For Sale  In Shri Ram Nagar In Aundh ',
#  '2 BHK Apartment  For Sale  In Achalare Tierra Viva In Baner ',
#  '2 BHK Flat  For Sale  In The Leaf In Kondwa Budruk ',
# ...

# %%
location = []
for i in soup.find_all ('div', class_ = 'nb__1EwQz'):
    location.append(i.text)
location
# Out:
# ['Anshul Eva housing Society\xa0 ASHUL EVA SOCIETY, Siddharth Nagar, Bavdhan.',
#  'Amit Colori\xa0 Amit Colori ph 2 hadpsar Mohmadwadi rd, near, chowk, Undri, Pune, Maharashtra',
#  'Indira Nagar, Chinchwad, Pune Maharashtra, INDIA ',
#  'Nilgiri Lane, Beside Sindh Society',
#  'Vaidehi Riviera\xa0 No E, Lane 4, Bavdhan, Pune, Maharashtra 411021, India',
#  'Pune Banglore Highway Pashan Exit Aditya Garden City, Warje Pune, Maharashtra',
#  'River Residency\xa0 Dehu-Alandi road, Jadhav Wadi,Near SNBP INTERNATIONAL SCHOOL & COLLEGE',
#  'Rps Tower\xa0 Swami Samarth, 278, Sathe Nagar, Lohgaon,, Kutwal Colony, Lohegaon',
#  'C401,s no 17/4 datta mandir road beside wakad police station 411033',
#  'behind bollywood theatre Survey no 50 mahadev nagar near gajanan maharaj temple wadgaon sheri pune',
#  'Nilay Paradise\xa0 d mart',
#  'Opposite Mont Vert Tranquille, Datta Mandir Road, Wakad, Pune, Maharashtra, INDIA.',
#  'Ranjeet Ss Tanishque Garden\xa0 Wadachi Wadi Road, Undri.',
# ...

# %%
header = []
for i in soup.find_all ('div', class_ = 'font-semi-bold heading-6'):
    header.append(i.text)
header
# Out:
# ['1,498 sqft',
#  '₹57,314/Month',
#  '₹1 Crore',
#  '750 sqft',
#  '₹23,498/Month',
#  '₹41 Lacs',
#  '725 sqft',
#  '₹32,898/Month',
#  '₹57.4 Lacs',
#  '1,130 sqft',
#  '₹65,911/Month',
#  '₹1.15 Crores',
#  '1,198 sqft',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '1,089 sqft',
#  '₹51,583/Month',
#  '₹90 Lacs',
#  '630 sqft',
#  '₹20,060/Month',
#  '₹35 Lacs',
#  '1,250 sqft',
#  '₹32,669/Month',
#  '₹57 Lacs',
#  '1,108 sqft',
#  '₹49,863/Month',
#  '₹87 Lacs',
#  '971 sqft',
#  '₹40,120/Month',
#  '₹70 Lacs',
#  '634 sqft',
#  '₹20,060/Month',
#  '₹35 Lacs',
#  '1,134 sqft',
#  '₹41,839/Month',
#  '₹73 Lacs',
#  '2,413 sqft',
#  '₹68,777/Month',
#  '₹1.2 Crores',
#  '494 sqft',
#  '₹33,242/Month',
#  '₹58 Lacs',
#  '904 sqft',
#  '₹46,997/Month',
#  '₹82 Lacs',
#  '990 sqft',
#  '₹29,803/Month',
#  '₹52 Lacs',
#  '546 sqft',
#  '₹28,657/Month',
#  '₹50 Lacs',
#  '1,038 sqft',
#  '₹42,126/Month',
#  '₹73.5 Lacs',
#  '660 sqft',
#  '₹21,779/Month',
#  '₹38 Lacs',
#  '578 sqft',
# ...

# %%
del header[0:76:3]
header
# Out:
# ['₹57,314/Month',
#  '₹1 Crore',
#  '₹23,498/Month',
#  '₹41 Lacs',
#  '₹32,898/Month',
#  '₹57.4 Lacs',
#  '₹65,911/Month',
#  '₹1.15 Crores',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '₹51,583/Month',
#  '₹90 Lacs',
#  '₹20,060/Month',
#  '₹35 Lacs',
#  '₹32,669/Month',
#  '₹57 Lacs',
#  '₹49,863/Month',
#  '₹87 Lacs',
#  '₹40,120/Month',
#  '₹70 Lacs',
#  '₹20,060/Month',
#  '₹35 Lacs',
#  '₹41,839/Month',
#  '₹73 Lacs',
#  '₹68,777/Month',
#  '₹1.2 Crores',
#  '₹33,242/Month',
#  '₹58 Lacs',
#  '₹46,997/Month',
#  '₹82 Lacs',
#  '₹29,803/Month',
#  '₹52 Lacs',
#  '₹28,657/Month',
#  '₹50 Lacs',
#  '₹42,126/Month',
#  '₹73.5 Lacs',
#  '₹21,779/Month',
#  '₹38 Lacs',
#  '₹13,182/Month',
#  '₹23 Lacs',
#  '₹51,583/Month',
#  '₹90 Lacs',
#  '₹31,522/Month',
#  '₹55 Lacs',
#  '₹28,657/Month',
#  '₹50 Lacs',
#  '₹18,340/Month',
#  '₹32 Lacs',
#  '₹56,168/Month',
#  '₹98 Lacs']

# %%
emi = header[0:51:2]
emi
# Out:
# ['₹57,314/Month',
#  '₹23,498/Month',
#  '₹32,898/Month',
#  '₹65,911/Month',
#  '₹48,717/Month',
#  '₹51,583/Month',
#  '₹20,060/Month',
#  '₹32,669/Month',
#  '₹49,863/Month',
#  '₹40,120/Month',
#  '₹20,060/Month',
#  '₹41,839/Month',
#  '₹68,777/Month',
#  '₹33,242/Month',
#  '₹46,997/Month',
#  '₹29,803/Month',
#  '₹28,657/Month',
#  '₹42,126/Month',
#  '₹21,779/Month',
#  '₹13,182/Month',
#  '₹51,583/Month',
#  '₹31,522/Month',
#  '₹28,657/Month',
#  '₹18,340/Month',
#  '₹56,168/Month']

# %%
price = header[1:51:2]
price
# Out:
# ['₹1 Crore',
#  '₹41 Lacs',
#  '₹57.4 Lacs',
#  '₹1.15 Crores',
#  '₹85 Lacs',
#  '₹90 Lacs',
#  '₹35 Lacs',
#  '₹57 Lacs',
#  '₹87 Lacs',
#  '₹70 Lacs',
#  '₹35 Lacs',
#  '₹73 Lacs',
#  '₹1.2 Crores',
#  '₹58 Lacs',
#  '₹82 Lacs',
#  '₹52 Lacs',
#  '₹50 Lacs',
#  '₹73.5 Lacs',
#  '₹38 Lacs',
#  '₹23 Lacs',
#  '₹90 Lacs',
#  '₹55 Lacs',
#  '₹50 Lacs',
#  '₹32 Lacs',
#  '₹98 Lacs']

# %%
print (len (location), len(title), len(emi), len (price))
# Out:
# 25 25 25 25

# %%
df4 = pd.DataFrame({'House title': title,'Location':location,'Area':'Pune','EMI':emi,'Price':price})
df4
# Out:
#                                           House title  \
# 0   3 BHK Apartment  For Sale  In Anshul Eva Housi...
# 1   2 BHK Apartment  For Sale  In Amit Colori In U...
# 2   2 BHK Flat  For Sale  In Ashirwad Sonai In Pim...
# 3          2 BHK Flat  For Sale  In Nalanda In Aundh
# 4   2 BHK Apartment  For Sale  In Vaidehi Riviera ...
# 5   2 BHK Flat  For Sale  In Adityas A Garden City...
# 6   1 BHK Apartment  For Sale  In River Residency ...
# 7   2 BHK Apartment  For Sale  In Rps Tower In Loh...
# 8   2 BHK Flat  For Sale  In Ivana Society In Waka...
# 9   2 BHK Flat  For Sale  In Sai Subhash Srushti I...
# 10  1 BHK Apartment  For Sale  In Nilay Paradise I...
# 11  2 BHK Flat  For Sale  In Crystal Heights In Wa...
# 12  3 BHK Apartment  For Sale  In Ranjeet Ss Tanis...
# 13        1 BHK For Sale  In Shri Ram Nagar In Aundh
# 14  2 BHK Apartment  For Sale  In Achalare Tierra ...
# 15  2 BHK Flat  For Sale  In The Leaf In Kondwa Bu...
# ...

# %%
#Gurgaon

# %%
page = requests.get ('https://www.nobroker.in/property/sale/gurgaon/Gurgaon/?searchParam=W3sibGF0IjoyOC40NTk0OTY1LCJsb24iOjc3LjAyNjYzODMsInBsYWNlSWQiOiJDaElKV1lqamd0VVpEVGtSSGt2RzVlaGZ6d0kiLCJwbGFjZU5hbWUiOiJHdXJnYW9uIiwic2hvd01hcCI6ZmFsc2V9XQ==')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
title = []
for i in soup.find_all ('h2', class_ = 'heading-6 font-semi-bold nb__25Cl7'):
    title.append(i.text)
title
# Out:
# ['3 BHK Apartment  For Sale  In Ansal Harmony Homes In Sector-57 ',
#  '3 BHK Flat  For Sale  In Krisumi Waterfall Residences In Sector-36  ',
#  '4 BHK In Independent House  For Sale  In Sector 52 ',
#  '4 BHK Flat  For Sale  In Orchid Island In Sector-51 ',
#  '3 BHK Flat  For Sale  In Orchid Island In Sector-51 ',
#  '2 BHK Flat  For Sale  In M3m Heights In Sector 65 ',
#  '3 BHK Flat  For Sale  In M3m Heights In Sector 65 ',
#  '3 BHK Flat  For Sale  In Bharat Properties Kps Group Bharat Residency In Sector 67 ',
#  '3 BHK Flat  For Sale  In Sobha City In Sector-108 ',
#  '4 BHK Flat  For Sale  In Suncity Platinum Towers In Sectory 28 ',
#  '4 BHK Flat  For Sale  In Aradhya Homes In Sector 67 ',
#  '3 BHK Flat  For Sale  In Godrej Serenity  In Sector 33 ',
#  '2 BHK Flat  For Sale  In Godrej Serenity  In Sector 33 ',
#  '2 BHK Flat  For Sale  In Godrej Nature Plus In Sec 33 ',
#  '3 BHK Flat  For Sale  In Godrej Nature Plus In Sec 33 ',
# ...

# %%
location = []
for i in soup.find_all ('div', class_ = 'nb__1EwQz'):
    location.append(i.text)
location
# Out:
# ['Ansal Harmony Homes\xa0 Harmony Homes, Sushant Lok III, Sector 57, Near Hongkong Bazar',
#  'Sector 36A, Gurgaon, Haryana , INDIA.',
#  'Independent House\xa0 Independent House, Near Petrol Pump',
#  'Sector-51, Gurgaon, Haryana, INDIA.',
#  'Sector-51, Gurgaon, Haryana, INDIA.',
#  'Golf Course Ext Rd, Sector 65, Gurugram, Haryana 122001, India',
#  'Golf Course Ext Rd, Sector 65, Gurugram, Haryana 122001, India',
#  'behind VIBGYOR High School, Gurgaon, Block D, Sector 67, Gurugram, Haryana, India',
#  'Chintels Metropolis, Sector-108, Nanak Heri Village, Gurgaon, Haryana, INDIA.',
#  'Sector 28, Gurgaon, Haryana',
#  'Ansal Versalia, Sector 67A,Sohna Road Gurgaon -122002, Haryana,Sector 67',
#  'Sohna Rd, Sector 33, Gurugram Sector 33',
#  'Sohna Rd, Sector 33, Gurugram, Haryana Sector 33',
#  'Sohna Sec 33, Sohna Rd',
#  'Sohna Sec 33, Sohna Rd',
#  'Sukh Shanti Apartment\xa0 Sector-56, Gurgaon, Haryana, INDIA.',
# ...

# %%
header = []
for i in soup.find_all ('div', class_ = 'font-semi-bold heading-6'):
    header.append(i.text)
header
# Out:
# ['1,800 sqft',
#  '₹68,777/Month',
#  '₹1.2 Crores',
#  '1,009 sqft',
#  '₹1.06 Lacs/Month',
#  '₹1.85 Crores',
#  '9,000 sqft',
#  '₹5.16 Lacs/Month',
#  '₹9 Crores',
#  '2,207 sqft',
#  '₹1.09 Lacs/Month',
#  '₹1.91 Crores',
#  '1,640 sqft',
#  '₹75,655/Month',
#  '₹1.32 Crores',
#  '1,433 sqft',
#  '₹1.08 Lacs/Month',
#  '₹1.89 Crores',
#  '1,828 sqft',
#  '₹1.41 Lacs/Month',
#  '₹2.46 Crores',
#  '1,200 sqft',
#  '₹34,961/Month',
#  '₹61 Lacs',
#  '1,131 sqft',
#  '₹1.09 Lacs/Month',
#  '₹1.91 Crores',
#  '3,150 sqft',
#  '₹2.76 Lacs/Month',
#  '₹4.82 Crores',
#  '2,100 sqft',
#  '₹85,971/Month',
#  '₹1.5 Crores',
#  '1,670 sqft',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '1,311 sqft',
#  '₹54,448/Month',
#  '₹95 Lacs',
#  '1,385 sqft',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '1,930 sqft',
#  '₹77,374/Month',
#  '₹1.35 Crores',
#  '2,400 sqft',
#  '₹80,240/Month',
#  '₹1.4 Crores',
#  '2,584 sqft',
#  '₹2.49 Lacs/Month',
#  '₹4.35 Crores',
#  '1,807 sqft',
#  '₹1.81 Lacs/Month',
# ...

# %%
del header[0:76:3]
header
# Out:
# ['₹68,777/Month',
#  '₹1.2 Crores',
#  '₹1.06 Lacs/Month',
#  '₹1.85 Crores',
#  '₹5.16 Lacs/Month',
#  '₹9 Crores',
#  '₹1.09 Lacs/Month',
#  '₹1.91 Crores',
#  '₹75,655/Month',
#  '₹1.32 Crores',
#  '₹1.08 Lacs/Month',
#  '₹1.89 Crores',
#  '₹1.41 Lacs/Month',
#  '₹2.46 Crores',
#  '₹34,961/Month',
#  '₹61 Lacs',
#  '₹1.09 Lacs/Month',
#  '₹1.91 Crores',
#  '₹2.76 Lacs/Month',
#  '₹4.82 Crores',
#  '₹85,971/Month',
#  '₹1.5 Crores',
#  '₹74,508/Month',
#  '₹1.3 Crores',
#  '₹54,448/Month',
#  '₹95 Lacs',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '₹77,374/Month',
#  '₹1.35 Crores',
#  '₹80,240/Month',
#  '₹1.4 Crores',
#  '₹2.49 Lacs/Month',
#  '₹4.35 Crores',
#  '₹1.81 Lacs/Month',
#  '₹3.15 Crores',
#  '₹50,436/Month',
#  '₹88 Lacs',
#  '₹1.06 Lacs/Month',
#  '₹1.86 Crores',
#  '₹1.84 Lacs/Month',
#  '₹3.22 Crores',
#  '₹1.3 Lacs/Month',
#  '₹2.27 Crores',
#  '₹1.07 Lacs/Month',
#  '₹1.87 Crores',
#  '₹1.15 Lacs/Month',
#  '₹2 Crores',
#  '₹2.24 Lacs/Month',
#  '₹3.9 Crores']

# %%
emi = header[0:51:2]
emi
# Out:
# ['₹68,777/Month',
#  '₹1.06 Lacs/Month',
#  '₹5.16 Lacs/Month',
#  '₹1.09 Lacs/Month',
#  '₹75,655/Month',
#  '₹1.08 Lacs/Month',
#  '₹1.41 Lacs/Month',
#  '₹34,961/Month',
#  '₹1.09 Lacs/Month',
#  '₹2.76 Lacs/Month',
#  '₹85,971/Month',
#  '₹74,508/Month',
#  '₹54,448/Month',
#  '₹48,717/Month',
#  '₹77,374/Month',
#  '₹80,240/Month',
#  '₹2.49 Lacs/Month',
#  '₹1.81 Lacs/Month',
#  '₹50,436/Month',
#  '₹1.06 Lacs/Month',
#  '₹1.84 Lacs/Month',
#  '₹1.3 Lacs/Month',
#  '₹1.07 Lacs/Month',
#  '₹1.15 Lacs/Month',
#  '₹2.24 Lacs/Month']

# %%
price = header[1:51:2]
price
# Out:
# ['₹1.2 Crores',
#  '₹1.85 Crores',
#  '₹9 Crores',
#  '₹1.91 Crores',
#  '₹1.32 Crores',
#  '₹1.89 Crores',
#  '₹2.46 Crores',
#  '₹61 Lacs',
#  '₹1.91 Crores',
#  '₹4.82 Crores',
#  '₹1.5 Crores',
#  '₹1.3 Crores',
#  '₹95 Lacs',
#  '₹85 Lacs',
#  '₹1.35 Crores',
#  '₹1.4 Crores',
#  '₹4.35 Crores',
#  '₹3.15 Crores',
#  '₹88 Lacs',
#  '₹1.86 Crores',
#  '₹3.22 Crores',
#  '₹2.27 Crores',
#  '₹1.87 Crores',
#  '₹2 Crores',
#  '₹3.9 Crores']

# %%
print (len (location), len(title), len(emi), len (price))
# Out:
# 25 25 25 25

# %%
df5 = pd.DataFrame({'House title': title,'Location':location,'Area':'Gurgaon','EMI':emi,'Price':price})
df5
# Out:
#                                           House title  \
# 0   3 BHK Apartment  For Sale  In Ansal Harmony Ho...
# 1   3 BHK Flat  For Sale  In Krisumi Waterfall Res...
# 2   4 BHK In Independent House  For Sale  In Secto...
# 3   4 BHK Flat  For Sale  In Orchid Island In Sect...
# 4   3 BHK Flat  For Sale  In Orchid Island In Sect...
# 5   2 BHK Flat  For Sale  In M3m Heights In Sector...
# 6   3 BHK Flat  For Sale  In M3m Heights In Sector...
# 7   3 BHK Flat  For Sale  In Bharat Properties Kps...
# 8   3 BHK Flat  For Sale  In Sobha City In Sector-...
# 9   4 BHK Flat  For Sale  In Suncity Platinum Towe...
# 10  4 BHK Flat  For Sale  In Aradhya Homes In Sect...
# 11  3 BHK Flat  For Sale  In Godrej Serenity  In S...
# 12  2 BHK Flat  For Sale  In Godrej Serenity  In S...
# 13  2 BHK Flat  For Sale  In Godrej Nature Plus In...
# 14  3 BHK Flat  For Sale  In Godrej Nature Plus In...
# 15  4 BHK Apartment  For Sale  In Sukh Shanti Apar...
# ...

# %%
df = pd.concat ([df1,df2,df3,df4,df5])
df
# Out:
#                                           House title  \
# 0   2 BHK Flat  For Sale  In Vijay Rajas Century C...
# 1   3 BHK Flat  For Sale  In Ceedeeyes Regal Palm ...
# 2   2 BHK Flat  For Sale  In Sai Palace In Sholing...
# 3   2 BHK Apartment  For Sale  In Jains Abhineet I...
# 4   4 BHK In Independent House  For Sale  In Iyyap...
# ..                                                ...
# 20  4+ BHK Flat  For Sale  In Ss Group The Leaf Gu...
# 21  4 BHK Flat  For Sale  In Godrej Air In Sector 85
# 22  3 BHK Flat  For Sale  In Godrej Air In Sector-85
# 23                4 BHK Flat  For Sale  In Sector 51
# 24  3 BHK Flat  For Sale  In Mahindra Luminare In ...
#
#                                              Location     Area  \
# 0   Melurkuppam Main Road,, Padur Village, Poonamm...  Chennai
# 1                   Next to Adyar Ananda Bhawan Hotel  Chennai
# 2                   near Sri Prathyangira Devi Temple  Chennai
# ...

# %%
len(df)
# Out:
# 125

# %%
df.reset_index(drop=True) 
#Result has all the flats for rent in all locations in the main website(Chennai, Bangalore, Mumbai, Pune, Gurgaon)
# Out:
#                                            House title  \
# 0    2 BHK Flat  For Sale  In Vijay Rajas Century C...
# 1    3 BHK Flat  For Sale  In Ceedeeyes Regal Palm ...
# 2    2 BHK Flat  For Sale  In Sai Palace In Sholing...
# 3    2 BHK Apartment  For Sale  In Jains Abhineet I...
# 4    4 BHK In Independent House  For Sale  In Iyyap...
# ..                                                 ...
# 120  4+ BHK Flat  For Sale  In Ss Group The Leaf Gu...
# 121  4 BHK Flat  For Sale  In Godrej Air In Sector 85
# 122  3 BHK Flat  For Sale  In Godrej Air In Sector-85
# 123                4 BHK Flat  For Sale  In Sector 51
# 124  3 BHK Flat  For Sale  In Mahindra Luminare In ...
#
#                                               Location     Area  \
# 0    Melurkuppam Main Road,, Padur Village, Poonamm...  Chennai
# 1                    Next to Adyar Ananda Bhawan Hotel  Chennai
# 2                    near Sri Prathyangira Devi Temple  Chennai
# ...
