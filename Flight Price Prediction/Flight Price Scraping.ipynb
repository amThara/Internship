# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\Lenovo\Desktop\DS\chromedriver.exe")
driver.get ('https://www.makemytrip.com/')

# %%
sear = driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div[2]/p/a')
sear.click()

# %%
for _ in range(1000):
        driver.execute_script("window.scrollBy(0,10000)")

airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)

df1 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Sunday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide visible left-2']")
sec.click()

# %%
for _ in range(1000):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df2 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Monday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-1']")
sec.click()

# %%
for _ in range(1000):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df3 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Tuesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df4 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Wednesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df5 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Thursday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide visible right-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df6 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Friday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide visible right-2']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df7 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Saturday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//input[@id = 'fromCity']")
sec.click()
sec.send_keys ('Chennai')
sel = driver.find_element_by_xpath("//li[@class= 'react-autosuggest__suggestion react-autosuggest__suggestion--first']")
sel.click()

# %%
sec = driver.find_element_by_xpath("//input[@id= 'toCity']")
sec.send_keys ('Mumbai')
sel = driver.find_element_by_xpath("//li[@class= 'react-autosuggest__suggestion react-autosuggest__suggestion--first']")
sel.click()

# %%
sec = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/header/div[1]/div/button/span")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df8 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Sunday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide visible left-3']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df9 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Monday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide visible left-2']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df10 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Tuesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide visible left-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df11 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Wednesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df12 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Thursday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df13 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Friday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class='weeklyFareItems glider-slide visible right-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df14 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Saturday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//input[@id = 'fromCity']")
sec.click()
sec.send_keys ('Kolkata')
sel = driver.find_element_by_xpath("//li[@class= 'react-autosuggest__suggestion react-autosuggest__suggestion--first']")
sel.click()

# %%
sec = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/header/div[1]/div/button/span")
sec.click()

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide active visible left-4']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df15 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Sunday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-3']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df16 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Monday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-2']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df17 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Tuesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df18 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Wednesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df19 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Thursday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df20 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Friday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible right-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df21 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Saturday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//input[@id = 'fromCity']")
sec.click()
sec.send_keys ('Kashmir')
sel = driver.find_element_by_xpath("//li[@class= 'react-autosuggest__suggestion']")
sel.click()

# %%
sec = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/header/div[1]/div/button/span")
sec.click()

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide active visible left-4']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df22 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Sunday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-2']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df24 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Tuesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df25 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Wednesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df26 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Thursday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df27 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Friday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible right-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df28 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Saturday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//input[@id= 'toCity']")
sec.send_keys ('Kanyakumari')
sel = driver.find_element_by_xpath("//li[@class= 'react-autosuggest__suggestion react-autosuggest__suggestion--first']")
sel.click()

# %%
sec = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/header/div[1]/div/button/span")
sec.click()

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide active visible left-4']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df29 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Sunday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-3']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df30 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Monday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-2']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df31 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Tuesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df32 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Wednesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df33 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Thursday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df34 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Friday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//input[@id = 'fromCity']")
sec.click()
sec.send_keys ('New Delhi')
sel = driver.find_element_by_xpath("//li[@class= 'react-autosuggest__suggestion react-autosuggest__suggestion--first']")
sel.click()

# %%
sec = driver.find_element_by_xpath("//input[@id= 'toCity']")
sec.send_keys ('Kochi')
sel = driver.find_element_by_xpath("//li[@class= 'react-autosuggest__suggestion react-autosuggest__suggestion--first']")
sel.click()

# %%
sec = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/header/div[1]/div/button/span")
sec.click()

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide active visible left-4']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df36 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Sunday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-3']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df37 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Monday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-2']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df38 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Tuesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible left-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df39 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Wednesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df40 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Thursday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide center visible']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df41 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Friday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'weeklyFareItems glider-slide visible right-1']")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[1]")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:101:2]

arrtime= []
arrtime = time[1:101:2]

place = []
plac = driver.find_elements_by_xpath("//div[@class='makeFlex flex-column flightTimeInfo']/p[2]")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:101:2]

destination = []
destination = place[1:101:2]

duration = []
duratio = driver.find_elements_by_xpath("//div[@class='stop-info flexOne']/p")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//p[@class='flightsLayoverInfo']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//p[@class='blackText fontSize18 blackFont white-space-no-wrap']")
for i in pric:
    pri = i.text
    price.append(pri)
    
df42 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Saturday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df36,df37,df38,df39,df40,df41,df42], axis = 0)

# %%
df
# Out:
#    Airline_Name Departure_Time Arrival_Time Day_of_Travel     Source  \
# 0        IndiGo          02:25        05:15        Sunday  New Delhi
# 1        IndiGo          03:50        06:40        Sunday  New Delhi
# 2        IndiGo          05:50        08:35        Sunday  New Delhi
# 3     Air India          06:10        08:55        Sunday  New Delhi
# 4      SpiceJet          06:05        09:00        Sunday  New Delhi
# ..          ...            ...          ...           ...        ...
# 28       IndiGo          09:15        14:15      Saturday  New Delhi
# 29    Air India          04:55        08:10      Saturday  New Delhi
# 30       IndiGo          17:55        21:05      Saturday  New Delhi
# 31     Go First          14:00        19:05      Saturday  New Delhi
# 32    Air India          16:55        20:10      Saturday  New Delhi
#
#    Destination   Duration           No_of_stops     Price
# 0    Bengaluru  02 h 50 m              Non stop   ₹ 8,160
# ...

# %%
driver = webdriver.Chrome(r"C:\Users\Lenovo\Desktop\DS\chromedriver.exe")
driver.get ('https://www.easemytrip.com/')

# %%
sec = driver.find_element_by_xpath("//div[@class = 'mobile-wi1 flig-show1']/div[2]/input[2]")
sec.click()

# %%
sec = driver.find_element_by_xpath("//span[@id= 'spn5']")
sec.click()

# %%
sel = driver.find_element_by_xpath("//input[@class = 'src_btn']")
sel.click()

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][1]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df101 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Monday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][2]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df102 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Tuesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][3]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df103 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Wednesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][4]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df104 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Thursday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][5]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df105 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Friday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][6]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df106 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Saturday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][7]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df107 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Sunday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
df_cl = pd.concat([df101,df102,df103,df104,df105,df106,df107], axis = 0)

# %%
dataframe = pd.concat ([df,df_cl])
dataframe
# Out:
#     Airline_Name Departure_Time Arrival_Time Day_of_Travel     Source  \
# 0         IndiGo          02:25        05:15        Sunday  New Delhi
# 1         IndiGo          03:50        06:40        Sunday  New Delhi
# 2         IndiGo          05:50        08:35        Sunday  New Delhi
# 3      Air India          06:10        08:55        Sunday  New Delhi
# 4       SpiceJet          06:05        09:00        Sunday  New Delhi
# ..           ...            ...          ...           ...        ...
# 139      Vistara          20:40        14:05        Sunday      Delhi
# 140      Vistara          19:50        14:05        Sunday      Delhi
# 141      Vistara          17:35        14:05        Sunday      Delhi
# 142      Vistara          16:05        14:05        Sunday      Delhi
# 143      Vistara          14:15        14:05        Sunday      Delhi
#
#     Destination   Duration No_of_stops    Price
# 0     Bengaluru  02 h 50 m    Non stop  ₹ 8,160
# ...

# %%
sec = driver.find_element_by_xpath("//input[@id= 'FromSector_show']")
sec.click()

# %%
sec = driver.find_element_by_xpath("//span[@id= 'spn12']")
sec.click()

# %%
sec = driver.find_element_by_xpath("//input[@id= 'Editbox13_show']")
sec.click()

# %%
sec = driver.find_element_by_xpath("//span[@id= 'spn12']")
sec.click()

# %%
sel = driver.find_element_by_xpath("//button[@id = 'btnSrch']")
sel.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df108 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Monday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][2]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df109 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Tuesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][3]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df110 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Wednesday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][4]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df111 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Thursday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][5]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df112 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Friday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][6]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df113 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Saturday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
sec = driver.find_element_by_xpath("//div[@class = 'min-ht ng-scope'][7]")
sec.click()

# %%
for _ in range(100):
        driver.execute_script("window.scrollBy(0,10000)")
        
airli = []
airl = driver.find_elements_by_xpath("//div[@class = 'col-md-7 col-sm-7 padd-lft airl-txt-n']/span[1]")
for i in airl:
    air = i.text
    airli.append(air)

time = []
tim = driver.find_elements_by_xpath("//span[@class = 'txt-r2-n ng-binding']")
for i in tim:
    ti = i.text
    time.append(ti)
    
deptime = []
deptime = time[0:500:2]

arrtime= []
arrtime = time[1:500:2]

place = []
plac = driver.find_elements_by_xpath("//span[@class = 'txt-r3-n ng-binding']")
for i in plac:
    pla = i.text
    place.append(pla)

source = []
source = place[0:500:2]

destination = []
destination = place[1:500:2]

duration = []
duratio = driver.find_elements_by_xpath("//span[@class = 'dura_md ng-binding']")
for i in duratio:
    durati = i.text
    duration.append(durati)

stops = []
stop = driver.find_elements_by_xpath("//span[@class = 'dura_md2 ng-scope']")
for i in stop:
    sto = i.text
    stops.append(sto)

price = []
pric = driver.find_elements_by_xpath("//div[@class = 'col-md-2 col-sm-2 col-xs-5 mr5 cle']")
for i in pric:
    pri = i.text
    price.append(pri)
price = [i.split('\n',)[0] for i in price]
    
df114 = pd.DataFrame({'Airline_Name':airli,'Departure_Time':deptime,'Arrival_Time':arrtime,'Day_of_Travel':'Sunday','Source': source,'Destination':destination,'Duration':duration,'No_of_stops':stops,'Price':price})

# %%
data = pd.concat ([dataframe,df108,df109,df110,df111,df112,df113,df114])
data
# Out:
#     Airline_Name Departure_Time Arrival_Time Day_of_Travel     Source  \
# 0         IndiGo          02:25        05:15        Sunday  New Delhi
# 1         IndiGo          03:50        06:40        Sunday  New Delhi
# 2         IndiGo          05:50        08:35        Sunday  New Delhi
# 3      Air India          06:10        08:55        Sunday  New Delhi
# 4       SpiceJet          06:05        09:00        Sunday  New Delhi
# ..           ...            ...          ...           ...        ...
# 97       Vistara          13:25        23:05        Friday  Hyderabad
# 98       Vistara          08:30        20:15        Friday  Hyderabad
# 99       Vistara          08:30        20:15        Friday  Hyderabad
# 100      Vistara          11:00        20:15        Friday  Hyderabad
# 101      Vistara          13:25        23:05        Friday  Hyderabad
#
#     Destination   Duration No_of_stops    Price
# 0     Bengaluru  02 h 50 m    Non stop  ₹ 8,160
# ...

# %%
driver.close()

# %%
data.to_excel('Flight_Price_Prediction.xls')
